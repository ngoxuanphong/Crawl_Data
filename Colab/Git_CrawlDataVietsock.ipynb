# %%
import pandas as pd

# %%
# !pip install selenium
# !apt-get update # to update ubuntu to correctly run apt install
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:8 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# ...

# %%
# %cd '/content/drive/MyDrive/Vietstock'
# Out:
# /content/drive/MyDrive/Vietstock

# %%
# %cd '/content/drive/MyDrive/Vietstock'
token = "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"
# !git config --global user.name "ngoxuanphong"
# !git config --global user.email "xuanphongcht@gmail.com"
# !git config --global user.password 'nxp123@@'
# Out:
# /content/drive/MyDrive/Vietstock

# %%
# !git clone https://{token}@github.com:ngoxuanphong/CrawlDataVietstock.git
# !git remote add origin https://{ngoxuanphong}:{ngoxuanphong}@github.com:ngoxuanphong/CrawlDataVietstock.git
# !git remote add origin 'https://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@github.com:ngoxuanphong/CrawlDataVietstock.git'
# Out:
# fatal: remote origin already exists.

# %%
# !git clone https://github.com/ngoxuanphong/CrawlDataVietstock.git
# %cd CrawlDataVietstock
# Out:
# /content/drive/MyDrive/Vietstock/CrawlDataVietstock

# %%
# !git add .
# !git commit -m 'hi'
# !git push origin main
# Out:
# [main e489495] hi
#  5 files changed, 36 insertions(+), 33 deletions(-)

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git pull origin main
# Out:
# From https://github.com/ngoxuanphong/CrawlDataVietstock
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !python test.py
# Out:
# 24H
# hi
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Vietstock/CrawlDataVietstock/base/FinanStatement.py", line 36, in getlink
#     self.driver.get(link)
#   File "/usr/local/lib/python3.7/dist-packages/selenium/webdriver/remote/webdriver.py", line 442, in get
#     self.execute(Command.GET, {'url': url})
#   File "/usr/local/lib/python3.7/dist-packages/selenium/webdriver/remote/webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.7/dist-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.TimeoutException: Message: timeout: Timed out receiving message from renderer: 0.521
#   (Session info: headless chrome=101.0.4951.64)
# Stacktrace:
# #0 0x55e115b82553 <unknown>
# #1 0x55e11586d183 <unknown>
# #2 0x55e11585b610 <unknown>
# #3 0x55e11585a3a9 <unknown>
# ...

# %%
# !python test.py
